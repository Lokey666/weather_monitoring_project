# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os


raw_csv = r"C:\weather_monitoring_project\Data\live_raw.csv"

df = pd.read_csv(raw_csv)
df
# Out:
#           id       city                         timestamp  temperature  \
# 0          1  Ahmedabad  2025-11-15 18:46:38.567400+00:00         20.2
# 1          2  Bengaluru  2025-11-15 18:46:38.376559+00:00         20.2
# 2          3     Bhopal  2025-11-15 18:46:38.737303+00:00         18.0
# 3          4    Chennai  2025-11-15 18:46:38.355079+00:00         27.0
# 4          5   Dehradun  2025-11-15 18:46:38.785387+00:00         11.4
# ...      ...        ...                               ...          ...
# 10030  10031    Lucknow  2025-12-16 05:47:41.347276+00:00         12.3
# 10031  10032     Mumbai  2025-12-16 05:47:41.088203+00:00         28.4
# 10032  10033      Patna  2025-12-16 05:47:41.339425+00:00         20.3
# 10033  10034       Pune  2025-12-16 05:47:41.285802+00:00         24.6
# 10034  10035      Surat  2025-12-16 05:47:41.522537+00:00         27.6
#
#        humidity  wind_speed    pm10   pm2_5  nitrogen_dioxide  ozone
# 0          46.0    3.500000   35.85   34.75             26.85   72.0
# 1          88.0    2.888889   44.85   43.15             36.95   53.0
# 2          28.0    2.000000   56.95   50.35             20.45   76.0
# 3          84.0    5.611111   59.25   50.05              8.05  113.0
# 4          55.0    2.194444   53.05   51.85             34.55  105.0
# ...         ...         ...     ...     ...               ...    ...
# 10030     100.0    3.305556  108.85  107.75             11.15   74.0
# 10031      35.0    4.111111   27.85   25.85             25.55   62.0
# 10032      68.0    3.194444  118.45  114.75             18.45   51.0
# 10033      34.0    5.000000   31.55   29.45             11.05   79.0
# 10034      27.0    3.694444   48.95   46.65             33.85   41.0
#
# [10035 rows x 10 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10035 entries, 0 to 10034
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                10035 non-null  int64
#  1   city              10035 non-null  object
#  2   timestamp         10035 non-null  object
#  3   temperature       10034 non-null  float64
#  4   humidity          10034 non-null  float64
#  5   wind_speed        10034 non-null  float64
#  6   pm10              10034 non-null  float64
#  7   pm2_5             10034 non-null  float64
#  8   nitrogen_dioxide  10034 non-null  float64
#  9   ozone             10034 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 784.1+ KB
#                 id   temperature      humidity    wind_speed          pm10  \
# count  10035.00000  10034.000000  10034.000000  10034.000000  10034.000000
# mean    5018.00000     21.195645     57.368447      2.827235     63.188748
# std     2896.99931      5.342151     21.026202      1.440608     41.655457
# min        1.00000      7.100000     12.000000      1.000000      2.850000
# 25%     2509.50000     17.200000     40.000000      1.888889     36.450000
# 50%     5018.00000     21.300000     55.000000      2.500000     53.800000
# 75%     7526.50000     25.300000     74.000000      3.388889     79.550000
# max    10035.00000     34.300000    100.000000     14.000000    338.950000
#
#               pm2_5  nitrogen_dioxide         ozone
# count  10034.000000      10034.000000  10034.000000
# mean      61.459249         22.696323     99.324796
# std       41.242658         19.805255     52.362864
# min        2.850000          0.850000      0.000000
# 25%       35.050000          8.350000     62.000000
# 50%       52.150000         18.250000     88.000000
# 75%       77.450000         31.850000    132.000000
# max      334.250000        179.150000    398.000000

# %%
df['timestamp'] = (
    pd.to_datetime(df['timestamp'], utc=True, errors='coerce')
        .dt.tz_convert('Asia/Kolkata')
)

# %%
df.isna().sum()
# Out:
# id                  0
# city                0
# timestamp           0
# temperature         1
# humidity            1
# wind_speed          1
# pm10                1
# pm2_5               1
# nitrogen_dioxide    1
# ozone               1
# dtype: int64

# %%
weather_cols = ['temperature','humidity','wind_speed']
df[weather_cols] = df[weather_cols].interpolate(method='linear')

# %%
poll_cols = ['pm10','pm2_5','nitrogen_dioxide','ozone']
df[poll_cols] = df[poll_cols].ffill()
df = df.bfill()

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

df['hour'] = df['timestamp'].dt.hour
df['day'] = df['timestamp'].dt.day
df['month'] = df['timestamp'].dt.month
df['weekday'] = df['timestamp'].dt.day_name()

# %%
df
# Out:
#           id       city                        timestamp  temperature  \
# 0          1  Ahmedabad 2025-11-16 00:16:38.567400+05:30         20.2
# 1          2  Bengaluru 2025-11-16 00:16:38.376559+05:30         20.2
# 2          3     Bhopal 2025-11-16 00:16:38.737303+05:30         18.0
# 3          4    Chennai 2025-11-16 00:16:38.355079+05:30         27.0
# 4          5   Dehradun 2025-11-16 00:16:38.785387+05:30         11.4
# ...      ...        ...                              ...          ...
# 10030  10031    Lucknow 2025-12-16 11:17:41.347276+05:30         12.3
# 10031  10032     Mumbai 2025-12-16 11:17:41.088203+05:30         28.4
# 10032  10033      Patna 2025-12-16 11:17:41.339425+05:30         20.3
# 10033  10034       Pune 2025-12-16 11:17:41.285802+05:30         24.6
# 10034  10035      Surat 2025-12-16 11:17:41.522537+05:30         27.6
#
#        humidity  wind_speed    pm10   pm2_5  nitrogen_dioxide  ozone  hour  \
# 0          46.0    3.500000   35.85   34.75             26.85   72.0     0
# 1          88.0    2.888889   44.85   43.15             36.95   53.0     0
# 2          28.0    2.000000   56.95   50.35             20.45   76.0     0
# 3          84.0    5.611111   59.25   50.05              8.05  113.0     0
# 4          55.0    2.194444   53.05   51.85             34.55  105.0     0
# ...         ...         ...     ...     ...               ...    ...   ...
# 10030     100.0    3.305556  108.85  107.75             11.15   74.0    11
# 10031      35.0    4.111111   27.85   25.85             25.55   62.0    11
# 10032      68.0    3.194444  118.45  114.75             18.45   51.0    11
# 10033      34.0    5.000000   31.55   29.45             11.05   79.0    11
# 10034      27.0    3.694444   48.95   46.65             33.85   41.0    11
#
#        day  month  weekday
# 0       16     11   Sunday
# 1       16     11   Sunday
# 2       16     11   Sunday
# 3       16     11   Sunday
# 4       16     11   Sunday
# ...    ...    ...      ...
# 10030   16     12  Tuesday
# 10031   16     12  Tuesday
# 10032   16     12  Tuesday
# 10033   16     12  Tuesday
# 10034   16     12  Tuesday
#
# [10035 rows x 14 columns]

# %%
print(df['timestamp'].head())
print(df['timestamp'].tail())
# Out:
# 0   2025-11-16 00:16:38.567400+05:30
# 1   2025-11-16 00:16:38.376559+05:30
# 2   2025-11-16 00:16:38.737303+05:30
# 3   2025-11-16 00:16:38.355079+05:30
# 4   2025-11-16 00:16:38.785387+05:30
# Name: timestamp, dtype: datetime64[ns, Asia/Kolkata]
# 10030   2025-12-16 11:17:41.347276+05:30
# 10031   2025-12-16 11:17:41.088203+05:30
# 10032   2025-12-16 11:17:41.339425+05:30
# 10033   2025-12-16 11:17:41.285802+05:30
# 10034   2025-12-16 11:17:41.522537+05:30
# Name: timestamp, dtype: datetime64[ns, Asia/Kolkata]

# %%
clean_path = r"C:\weather_monitoring_project\Data\clean_data.csv"
df.to_csv(clean_path, index=False)
