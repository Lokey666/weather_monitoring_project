# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv()

DB_URL = os.getenv('DATABASE_URL')

engine = create_engine(DB_URL)

df = pd.read_sql("SELECT * FROM weather_data", engine)
df['timestamp'] = df['timestamp'].dt.tz_convert('Asia/Kolkata')
df.head()
# Out:
#    id       city                        timestamp  temperature  humidity  \
# 0   1  Ahmedabad 2025-11-16 00:16:38.567400+05:30         20.2      46.0
# 1   2  Bengaluru 2025-11-16 00:16:38.376559+05:30         20.2      88.0
# 2   3     Bhopal 2025-11-16 00:16:38.737303+05:30         18.0      28.0
# 3   4    Chennai 2025-11-16 00:16:38.355079+05:30         27.0      84.0
# 4   5   Dehradun 2025-11-16 00:16:38.785387+05:30         11.4      55.0
#
#    wind_speed   pm10  pm2_5  nitrogen_dioxide  ozone
# 0    3.500000  35.85  34.75             26.85   72.0
# 1    2.888889  44.85  43.15             36.95   53.0
# 2    2.000000  56.95  50.35             20.45   76.0
# 3    5.611111  59.25  50.05              8.05  113.0
# 4    2.194444  53.05  51.85             34.55  105.0

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['hour'] = df['timestamp'].dt.hour
df['date'] = df['timestamp'].dt.date
today = df['date'].max()
df_today = df[df['date'] == today]
df_today
# Out:
#         id       city                        timestamp  temperature  humidity  \
# 990    991  Ahmedabad 2025-11-19 00:22:29.450159+05:30         19.1      52.0
# 991    992  Bengaluru 2025-11-19 00:22:29.258640+05:30         20.2      88.0
# 992    993     Bhopal 2025-11-19 00:22:29.659153+05:30         13.2      72.0
# 993    994    Chennai 2025-11-19 00:22:29.255975+05:30         24.3      94.0
# 994    995   Dehradun 2025-11-19 00:22:29.696376+05:30         12.6      62.0
# ...    ...        ...                              ...          ...       ...
# 1090  1091    Lucknow 2025-11-19 09:03:15.522606+05:30         19.1      78.0
# 1091  1092     Mumbai 2025-11-19 09:03:15.269016+05:30         24.2      44.0
# 1092  1093      Patna 2025-11-19 09:03:15.505822+05:30         22.1      65.0
# 1093  1094       Pune 2025-11-19 09:03:15.455542+05:30         20.5      40.0
# 1094  1095      Surat 2025-11-19 09:03:15.743940+05:30         23.0      39.0
#
#       wind_speed    pm10   pm2_5  nitrogen_dioxide  ozone  hour        date
# 990     2.805556   55.95   54.45             35.35   64.0     0  2025-11-19
# 991     3.805556   16.75   16.75             22.25   73.0     0  2025-11-19
# 992     2.000000   69.75   67.65             17.15   92.0     0  2025-11-19
# 993     4.305556   20.45   16.75              8.75   83.0     0  2025-11-19
# 994     2.000000   50.95   50.55             39.55   85.0     0  2025-11-19
# ...          ...     ...     ...               ...    ...   ...         ...
# 1090    1.194444  110.75  108.85             24.45   49.0     9  2025-11-19
# 1091    4.111111   57.85   56.35             31.65   57.0     9  2025-11-19
# 1092    1.000000  134.05  129.85             28.85   42.0     9  2025-11-19
# 1093    2.805556   53.45   50.55              9.45   85.0     9  2025-11-19
# 1094    4.111111   56.45   55.35             32.25   59.0     9  2025-11-19
#
# [105 rows x 12 columns]

# %%
temp_humidity = df_today.groupby('hour')[['temperature','humidity']].mean().reset_index()
temp_humidity
# Out:
#    hour  temperature   humidity
# 0     0    18.366667  67.800000
# 1     1    18.026667  68.800000
# 2     3    17.346667  71.800000
# 3     4    16.853333  73.666667
# 4     5    16.720000  74.133333
# 5     7    16.480000  75.733333
# 6     9    20.580000  61.733333

# %%
plt.figure(figsize=(10,6))

plt.plot(temp_humidity['hour'], temp_humidity['temperature'], marker='o', label='Temperature')
plt.plot(temp_humidity['hour'], temp_humidity['humidity'], marker='o', label='Humidity')

plt.xticks(range(0,24))

plt.xlabel("Hour of Day")
plt.ylabel("")
plt.title("Humidity and temperature move in opposite direction")
plt.grid(True)
plt.legend()
sns.despine()

plt.show()  #we dont have data for 6am and 8am
